# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt") 

results = model.train(
    data="dataset_french_signs/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    freeze=10, 
    name="french_signs",
    mixup=0.1, 
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.8 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.7 🚀 Python-3.13.8 torch-2.9.1 CPU (Apple M3)
# ...
